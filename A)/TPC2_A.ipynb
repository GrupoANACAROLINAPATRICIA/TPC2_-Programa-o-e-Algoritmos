# %% [markdown]
# TPC2 _ PARTE A)

# %% [markdown]
# 1) O URL para o conjunto de dados

# %%
http://centraldedados.pt/incendios2015.csv

ou repositorio da Github https://github.com/centraldedados/incendios/tree/master/data

# %% [markdown]
# 2) Fundamentem a escolha deste conjunto de dados;

# %%
Todos os anos Portugal passa por grandes dificuldades relativamente ao risco de incêndios, pelo que ficamos curiosas 
em tentar entender um pouco os dados que são recolhidos relativamente a este assunto.

# %% [markdown]
# 3) Escrevam um explicação do conjunto de dados, um Dicionário dos dados, que deve ficar no Readme do repositório.

# %%
situado no Readme A - 3, do repositório

# %% [markdown]
# 4) Escrevam o código que carrega o conjunto de dados usando a função read_csv e mostrem as
# 10 primeiras linhas do conjunto de dados.

# %%
import csv
import numpy as np
import pandas as pd

df = pd.read_csv("incendios2015.csv")
df.head(10)
# Out:
#     ano codigo_sgif    codigo_anpc          tipo          distrito  \
# 0  2015    DM315252  2015160007544     Florestal  Viana do Castelo
# 1  2015    DM215305  2015130043758     Florestal             Porto
# 2  2015    DM415293  2015030021973     Florestal             Braga
# 3  2015    DM315261  2015160007563  Falso Alarme  Viana do Castelo
# 4  2015    BL115321  2015180015874      Agrícola             Viseu
# 5  2015    DM415289  2015030021952     Florestal             Braga
# 6  2015    TM115382  2015170006397     Florestal         Vila Real
# 7  2015     BL21592  2015060013192  Falso Alarme           Coimbra
# 8  2015    DM215334  2015130044169     Florestal             Porto
# 9  2015    TM115385  2015170006446     Florestal         Vila Real
#
#               concelho            freguesia  \
# 0        Ponte de Lima            Serdedelo
# 1   Marco de Canaveses   Vila Boa de Quires
# 2           Vila Verde                 Lage
# 3        Ponte de Lima             Boalhosa
# ...

# %% [markdown]
# 5) Qual é o tipo de dados de cada atributo?

# %%
df.dtypes
# Out:
# ano                            int64
# codigo_sgif                   object
# codigo_anpc                    int64
# tipo                          object
# distrito                      object
# concelho                      object
# freguesia                     object
# local                         object
# ine                            int64
# x                              int64
# y                              int64
# lat                           object
# lon                           object
# data_alerta                   object
# hora_alerta                   object
# data_extincao                 object
# hora_extincao                 object
# data_primeira_intervencao     object
# hora_primeira_intervencao     object
# fonte_alerta                 float64
# nut                           object
# area_povoamento              float64
# area_mato                    float64
# area_agricola                float64
# area_pov_mato                float64
# ...
